# %%
import os
import cv2
import pytesseract
import pandas as pd
import re
from pathlib import Path
from datetime import datetime

# Function to extract temperature and time data from an image
def extract_data_from_image(image_path):
    # Read the image
    img = cv2.imread(image_path)
    
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply threshold to get a binary image
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    
    # Extract text using pytesseract
    text = pytesseract.image_to_string(thresh)
    
    # Create a copy of the image for visualization (optional)
    img_copy = img.copy()
    
    # Initialize variables
    max_temp = None
    min_temp = None
    center_temp = None
    timestamp = None
    
    # For thermal images, extract text from specific regions
    # Extract from top-left corner (for Cen and Max values)
    height, width = img.shape[:2]
    top_left_roi = img[0:int(height*0.15), 0:int(width*0.2)]
    top_left_text = pytesseract.image_to_string(top_left_roi)
    
    # Extract from bottom of image (for timestamp)
    bottom_roi = img[int(height*0.85):height, 0:int(width*0.5)]
    bottom_text = pytesseract.image_to_string(bottom_roi)
    
    # Extract from right side (for min value)
    right_roi = img[int(height*0.7):height, int(width*0.8):width]
    right_text = pytesseract.image_to_string(right_roi)
    
    # Combine all extracted text
    all_text = text + " " + top_left_text + " " + bottom_text + " " + right_text
    
    # Search for center temperature (labeled as "Cen")
    cen_temp_match = re.search(r'Cen\s*(\d+\.\d+)', all_text)
    if cen_temp_match:
        center_temp = cen_temp_match.group(1)
    
    # Search for maximum temperature (labeled as "Max")
    max_temp_match = re.search(r'Max\s*(\d+\.\d+)', all_text)
    if max_temp_match:
        max_temp = max_temp_match.group(1)
    
    # Search for minimum temperature (often at bottom right)
    min_temp_match = re.search(r'(\d+\.\d+)\s*$', right_text)
    if min_temp_match:
        min_temp = min_temp_match.group(1)
    else:
        # Alternative: look for lowest number in the right side of the image
        temp_matches = re.findall(r'(\d+\.\d+)', right_text)
        if temp_matches:
            min_temp = min(temp_matches, key=float)
    
    # Search for timestamp (format: YYYY/MM/DD HH:MM(AM/PM))
    timestamp_match = re.search(r'(\d{4}/\d{2}/\d{2}\s*\d{2}:\d{2}(?:AM|PM)?)', all_text)
    if timestamp_match:
        timestamp = timestamp_match.group(1)
    
    # If no timestamp found, try to extract from bottom part with common formats
    if not timestamp:
        timestamp_alt_match = re.search(r'(\d{4}[-/]\d{2}[-/]\d{2}\s*\d{1,2}:\d{2}(?::\d{2})?(?:\s*[AP]M)?)', bottom_text)
        if timestamp_alt_match:
            timestamp = timestamp_alt_match.group(1)
    
    # Print extracted data for debugging
    print(f"File: {os.path.basename(image_path)}")
    print(f"Center: {center_temp}, Max: {max_temp}, Min: {min_temp}, Time: {timestamp}")
    
    return {
        'file_name': os.path.basename(image_path),
        'center_temp': center_temp,
        'max_temp': max_temp,
        'min_temp': min_temp,
        'timestamp': timestamp
    }

# Main function to process all images in a folder
def process_folder(folder_path, output_csv):
    # Get all image files in the folder
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']
    image_files = [str(f) for f in Path(folder_path).iterdir() 
                  if f.is_file() and f.suffix.lower() in image_extensions]
    
    if not image_files:
        print(f"No image files found in {folder_path}")
        return
    
    # Process each image and collect data
    results = []
    for i, img_path in enumerate(image_files):
        print(f"Processing image {i+1}/{len(image_files)}: {os.path.basename(img_path)}")
        try:
            data = extract_data_from_image(img_path)
            results.append(data)
        except Exception as e:
            print(f"Error processing {img_path}: {str(e)}")
    
    # Create DataFrame and save to CSV
    if results:
        df = pd.DataFrame(results)
        df.to_csv(output_csv, index=False)
        print(f"Data extracted and saved to {output_csv}")
    else:
        print("No data was successfully extracted")

# Example usage
if __name__ == "__main__":
    folder_path = input("Enter the path to the folder containing images: ")
    output_csv = input("Enter the output CSV file path (default: temperature_data.csv): ") or "temperature_data.csv"
    
    process_folder(folder_path, output_csv)
# Out:
# Enter the path to the folder containing images:  C:\Users\Anuska Palit\OneDrive\Desktop\project\Computer Vision\Thermal Imaging.v8i.yolov8\valid\images
# Enter the output CSV file path (default: temperature_data.csv):  C:\Users\Anuska Palit\OneDrive\Desktop\project\Computer Vision\data3.csv
# Processing image 1/110: DIVU20240822115507_jpeg.rf.72b72f6c88deda0e18079589504fb743.jpg
# File: DIVU20240822115507_jpeg.rf.72b72f6c88deda0e18079589504fb743.jpg
# Center: 38.1, Max: 49.3, Min: 0.93, Time: 2024/08/22 11:55AM
# Processing image 2/110: DIVU20240822120117_jpeg.rf.ba40e13f9abcb70bbb1dcc3f79d51dcd.jpg
# File: DIVU20240822120117_jpeg.rf.ba40e13f9abcb70bbb1dcc3f79d51dcd.jpg
# Center: 28.9, Max: 34.8, Min: 10.93, Time: 2024/08/22 12:01PM
# Processing image 3/110: DIVU20240822144453_jpeg.rf.190bff8d4cba2fd5fe2fef21448eb3ca.jpg
# File: DIVU20240822144453_jpeg.rf.190bff8d4cba2fd5fe2fef21448eb3ca.jpg
# Center: 39.1, Max: 46.4, Min: 0.93, Time: 2024/08/22 02:44PM
# Processing image 4/110: DIVU20240822144702_jpeg.rf.a5332050ff4dcfbbd45e097341e70255.jpg
# File: DIVU20240822144702_jpeg.rf.a5332050ff4dcfbbd45e097341e70255.jpg
# Center: 38.2, Max: None, Min: None, Time: 2024/08/22 02:47PM
# Processing image 5/110: DIVU20240822150556_jpeg.rf.4b8353d8ed58dddfa35cbc9d6f346323.jpg
# File: DIVU20240822150556_jpeg.rf.4b8353d8ed58dddfa35cbc9d6f346323.jpg
# Center: 34.5, Max: 46.6, Min: 0.93, Time: 2024/08/22 03:05PM
# Processing image 6/110: DIVU20240905125020_jpeg.rf.1f5f525c0f2db9d99532d1d068489551.jpg
# File: DIVU20240905125020_jpeg.rf.1f5f525c0f2db9d99532d1d068489551.jpg
# Center: 41.6, Max: 63.8, Min: 0.93, Time: 2024/09/05 12:50PM
# Processing image 7/110: DIVU20240905125448_jpeg.rf.019e0d07be0f37749b6451501bcd6647.jpg
# File: DIVU20240905125448_jpeg.rf.019e0d07be0f37749b6451501bcd6647.jpg
# Center: 33.2, Max: 40.5, Min: 0.93, Time: 2024/09/05 12:54PM
# Processing image 8/110: DIVU20240905133806_jpeg.rf.84ff8eaa06e177a996c65b78e50245ee.jpg
# File: DIVU20240905133806_jpeg.rf.84ff8eaa06e177a996c65b78e50245ee.jpg
# Center: 42.8, Max: None, Min: 10.93, Time: 2024/09/05 01:38PM
# Processing image 9/110: DIVU20240905145930_jpeg.rf.53e7df198cac2155e95a3c9106d2e2f1.jpg
# File: DIVU20240905145930_jpeg.rf.53e7df198cac2155e95a3c9106d2e2f1.jpg
# Center: 41.3, Max: 52.4, Min: 60.93, Time: 2024/09/05 02:59PM
# Processing image 10/110: DIVU20240905161022_jpeg.rf.7cb6f90fdc9198d5dd24f89f4377e304.jpg
# File: DIVU20240905161022_jpeg.rf.7cb6f90fdc9198d5dd24f89f4377e304.jpg
# Center: None, Max: 29.9, Min: 0.93, Time: None
# Processing image 11/110: DIVU20240912091227_jpeg.rf.297672cbba18f78ea623d54d0a229200.jpg
# File: DIVU20240912091227_jpeg.rf.297672cbba18f78ea623d54d0a229200.jpg
# Center: 37.3, Max: 44.7, Min: 0.93, Time: 2024/09/12 09:12AM
# Processing image 12/110: DIVU20240912091918_jpeg.rf.ca7c81384c3cc46e07868479c4fadbd9.jpg
# File: DIVU20240912091918_jpeg.rf.ca7c81384c3cc46e07868479c4fadbd9.jpg
# Center: 35.8, Max: 38.7, Min: None, Time: None
# Processing image 13/110: DIVU20240912094831_jpeg.rf.a9b9795bfcef80a81e415b7c1692b158.jpg
# File: DIVU20240912094831_jpeg.rf.a9b9795bfcef80a81e415b7c1692b158.jpg
# Center: 33.1, Max: 46.3, Min: 50.93, Time: 2024/09/12 09:48AM
# Processing image 14/110: DIVU20240912094838_jpeg.rf.48f9b90d9a1fbf259d45336291f6b901.jpg
# File: DIVU20240912094838_jpeg.rf.48f9b90d9a1fbf259d45336291f6b901.jpg
# Center: 40.3, Max: 45.4, Min: None, Time: None
# Processing image 15/110: DIVU20240912094845_jpeg.rf.14b61ab2d97ed294ecc4cc1e8abe119e.jpg
# File: DIVU20240912094845_jpeg.rf.14b61ab2d97ed294ecc4cc1e8abe119e.jpg
# Center: 35.8, Max: 49.1, Min: 0.93, Time: 2024/09/12 09:48AM
# Processing image 16/110: DIVU20240912103921_jpeg.rf.36bcb2455ab42593e12c39bfac43c147.jpg
# File: DIVU20240912103921_jpeg.rf.36bcb2455ab42593e12c39bfac43c147.jpg
# Center: 33.5, Max: 36.0, Min: 0.93, Time: 2024/09/12 10:39AM
# Processing image 17/110: DIVU20240912115130_jpeg.rf.fa80c29278ad171715b6049978ff547b.jpg
# File: DIVU20240912115130_jpeg.rf.fa80c29278ad171715b6049978ff547b.jpg
# Center: 34.9, Max: 38.6, Min: 28.8, Time: 2029/09/12 11:51AM
# Processing image 18/110: DIVU20240912121055_jpeg.rf.0938c22ddf803c45c403dbb4636bc2a4.jpg
# File: DIVU20240912121055_jpeg.rf.0938c22ddf803c45c403dbb4636bc2a4.jpg
# Center: 51.2, Max: 61.0, Min: 0.93, Time: None
# Processing image 19/110: DIVU20240912123704_jpeg.rf.85d26e5b19676b9ee25c9f546a72b57e.jpg
# File: DIVU20240912123704_jpeg.rf.85d26e5b19676b9ee25c9f546a72b57e.jpg
# Center: 34.3, Max: 38.3, Min: 0.98, Time: 2024/09/12 12:37PM
# Processing image 20/110: DIVU20240912132300_jpeg.rf.b2759d49e3cb29911bf430bc3337cbd9.jpg
# File: DIVU20240912132300_jpeg.rf.b2759d49e3cb29911bf430bc3337cbd9.jpg
# Center: 29.4, Max: 44.6, Min: 0.93, Time: 2024/09/12 01:22PM
# Processing image 21/110: DIVU20240912144049_jpeg.rf.50ea6836bfe1d0a95cfc8dc810115c3f.jpg
# File: DIVU20240912144049_jpeg.rf.50ea6836bfe1d0a95cfc8dc810115c3f.jpg
# Center: 36.6, Max: 44.7, Min: 0.93, Time: 2024/09/12 02:40PM
# Processing image 22/110: DIVU20240912163118_jpeg.rf.5abe38d85c5dfbe5e927aded48d524dd.jpg
# File: DIVU20240912163118_jpeg.rf.5abe38d85c5dfbe5e927aded48d524dd.jpg
# Center: 47.5, Max: 75.2, Min: None, Time: None
# Processing image 23/110: DIVU20240912164733_jpeg.rf.cebb97c7fa5507c2a8b7b6906e8e18f3.jpg
# File: DIVU20240912164733_jpeg.rf.cebb97c7fa5507c2a8b7b6906e8e18f3.jpg
# Center: 35.0, Max: 52.4, Min: 0.93, Time: 2024/09/12 04:47PM
# Processing image 24/110: DIVU20240912165139_jpeg.rf.a62c38046fbf2fa7b948f858aa4ea9f7.jpg
# File: DIVU20240912165139_jpeg.rf.a62c38046fbf2fa7b948f858aa4ea9f7.jpg
# Center: 39.6, Max: 59.4, Min: 10.93, Time: 2024/09/12 04:51PM
# Processing image 25/110: DIVU20240912171752_jpeg.rf.87a86f57323186b73ac4cc4c4625b467.jpg
# File: DIVU20240912171752_jpeg.rf.87a86f57323186b73ac4cc4c4625b467.jpg
# Center: 41.3, Max: 60.3, Min: 0.93, Time: 2024/09/12 05:17PM
# Processing image 26/110: DIVU20240912171804_jpeg.rf.9dba26f6d358f687cd0dfe623bb308e3.jpg
# File: DIVU20240912171804_jpeg.rf.9dba26f6d358f687cd0dfe623bb308e3.jpg
# Center: None, Max: 60.55, Min: None, Time: None
# Processing image 27/110: DIVU20240912173131_jpeg.rf.cdbb0d36b2d1b9f33113a0be73b0ac0a.jpg
# File: DIVU20240912173131_jpeg.rf.cdbb0d36b2d1b9f33113a0be73b0ac0a.jpg
# Center: None, Max: 37.7, Min: None, Time: None
# Processing image 28/110: DIVU20240912174733_jpeg.rf.aaba85c2f8e876e9ff05c45030141d44.jpg
# File: DIVU20240912174733_jpeg.rf.aaba85c2f8e876e9ff05c45030141d44.jpg
# Center: 36.8, Max: 51.6, Min: 0.93, Time: 2024/09/12 05:47PM
# Processing image 29/110: DIVU20240912174745_jpeg.rf.00bae0d5c567426a7e03067379547e3b.jpg
# File: DIVU20240912174745_jpeg.rf.00bae0d5c567426a7e03067379547e3b.jpg
# Center: 40.4, Max: 51.0, Min: 50.93, Time: 2024/09/12 05:47PM
# Processing image 30/110: IR_28733_jpg.rf.ac5533265c062611158099029487722f.jpg
# File: IR_28733_jpg.rf.ac5533265c062611158099029487722f.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 31/110: IR_28739_jpg.rf.53b0b2c0394d145258820db389044185.jpg
# File: IR_28739_jpg.rf.53b0b2c0394d145258820db389044185.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 32/110: IR_28753_jpg.rf.0e346c3ade1a3f4d8ffb70fe3ca683d6.jpg
# File: IR_28753_jpg.rf.0e346c3ade1a3f4d8ffb70fe3ca683d6.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 33/110: IR_28755_jpg.rf.019ecc7543f60e8b2a518bb1f955925d.jpg
# File: IR_28755_jpg.rf.019ecc7543f60e8b2a518bb1f955925d.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 34/110: IR_30619_jpg.rf.57b4054a16eca8e3607aca7d23077226.jpg
# File: IR_30619_jpg.rf.57b4054a16eca8e3607aca7d23077226.jpg
# Center: None, Max: None, Min: 31.1, Time: None
# Processing image 35/110: IR_30623_jpg.rf.eab4374e5166fbe7aa73e1c32d9bfebf.jpg
# File: IR_30623_jpg.rf.eab4374e5166fbe7aa73e1c32d9bfebf.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 36/110: IR_30651_jpg.rf.850438cd4288b77de3e00c86b8f77eb9.jpg
# File: IR_30651_jpg.rf.850438cd4288b77de3e00c86b8f77eb9.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 37/110: IR_30653_jpg.rf.b0032fe1dab5bb3d6e0dc9a0a9c3957c.jpg
# File: IR_30653_jpg.rf.b0032fe1dab5bb3d6e0dc9a0a9c3957c.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 38/110: IR_30663_jpg.rf.072d27c702b17a29ce491d55aa609749.jpg
# File: IR_30663_jpg.rf.072d27c702b17a29ce491d55aa609749.jpg
# Center: None, Max: None, Min: 28.6, Time: None
# Processing image 39/110: IR_30665_jpg.rf.84c4e046efab271640c925d521fa3db0.jpg
# File: IR_30665_jpg.rf.84c4e046efab271640c925d521fa3db0.jpg
# Center: None, Max: None, Min: 29.5, Time: None
# Processing image 40/110: IR_30669_jpg.rf.2a69149f2068c277d4e81e6143ec01d2.jpg
# File: IR_30669_jpg.rf.2a69149f2068c277d4e81e6143ec01d2.jpg
# Center: None, Max: None, Min: 32.1, Time: None
# Processing image 41/110: IR_30675_jpg.rf.d6d9e465380eef71d73b2af785f5dd28.jpg
# File: IR_30675_jpg.rf.d6d9e465380eef71d73b2af785f5dd28.jpg
# Center: None, Max: None, Min: 33.6, Time: None
# Processing image 42/110: IR_30689_jpg.rf.cc6400610465452ffb79cf717d54f477.jpg
# File: IR_30689_jpg.rf.cc6400610465452ffb79cf717d54f477.jpg
# Center: None, Max: None, Min: 28.2, Time: None
# Processing image 43/110: IR_30707_jpg.rf.b31bf9c4a5cc44d5b51ef108b83da373.jpg
# File: IR_30707_jpg.rf.b31bf9c4a5cc44d5b51ef108b83da373.jpg
# Center: None, Max: None, Min: 1.16, Time: None
# Processing image 44/110: IR_30713_jpg.rf.5cc2534a4aec12364a3c9ea5137ab94d.jpg
# File: IR_30713_jpg.rf.5cc2534a4aec12364a3c9ea5137ab94d.jpg
# Center: None, Max: 78.2, Min: 28.1, Time: None
# Processing image 45/110: IR_30715_jpg.rf.d709c60518884f17874325c049c43e9b.jpg
# File: IR_30715_jpg.rf.d709c60518884f17874325c049c43e9b.jpg
# Center: None, Max: None, Min: 0.6, Time: None
# Processing image 46/110: IR_30717_jpg.rf.d6ec989ac9cb5877102c91323b9013fc.jpg
# File: IR_30717_jpg.rf.d6ec989ac9cb5877102c91323b9013fc.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 47/110: IR_30721_jpg.rf.a682fa6ad01d8e4849bf268b80c889f7.jpg
# File: IR_30721_jpg.rf.a682fa6ad01d8e4849bf268b80c889f7.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 48/110: IR_30723_jpg.rf.1106e0719dfbcb86dc76e8ec26604a2b.jpg
# File: IR_30723_jpg.rf.1106e0719dfbcb86dc76e8ec26604a2b.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 49/110: IR_30886_jpg.rf.0ba28e468f7a9cf6f70aac5adbd29733.jpg
# File: IR_30886_jpg.rf.0ba28e468f7a9cf6f70aac5adbd29733.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 50/110: IR_30908_jpg.rf.e869f2e8332fd4f3d6f69783e1eea71b.jpg
# File: IR_30908_jpg.rf.e869f2e8332fd4f3d6f69783e1eea71b.jpg
# Center: None, Max: 69.0, Min: 32.4, Time: None
# Processing image 51/110: IR_30918_jpg.rf.7f30556727c879084a2ed53bc976263d.jpg
# File: IR_30918_jpg.rf.7f30556727c879084a2ed53bc976263d.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 52/110: IR_30934_jpg.rf.0b05a53b7ea34112b769da19dd093369.jpg
# File: IR_30934_jpg.rf.0b05a53b7ea34112b769da19dd093369.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 53/110: IR_30940_jpg.rf.6022b803f9fd3e01898e79cabff467be.jpg
# File: IR_30940_jpg.rf.6022b803f9fd3e01898e79cabff467be.jpg
# Center: None, Max: None, Min: 34.3, Time: None
# Processing image 54/110: IR_30946_jpg.rf.34c9c84cc844013732433f79b2bdc97c.jpg
# File: IR_30946_jpg.rf.34c9c84cc844013732433f79b2bdc97c.jpg
# Center: None, Max: None, Min: 29.5, Time: None
# Processing image 55/110: IR_30948_jpg.rf.8307f00364216add7200ff870d6e3f7b.jpg
# File: IR_30948_jpg.rf.8307f00364216add7200ff870d6e3f7b.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 56/110: IR_30958_jpg.rf.f9b99de49891e4e410b8ece118bdb810.jpg
# File: IR_30958_jpg.rf.f9b99de49891e4e410b8ece118bdb810.jpg
# Center: None, Max: None, Min: 31.9, Time: None
# Processing image 57/110: IR_30974_jpg.rf.b4c119b6792337edbd1b3035567bd328.jpg
# File: IR_30974_jpg.rf.b4c119b6792337edbd1b3035567bd328.jpg
# Center: None, Max: None, Min: 30.7, Time: None
# Processing image 58/110: IR_30988_jpg.rf.304d383a51f68fd0519c0bdfc19a4baa.jpg
# File: IR_30988_jpg.rf.304d383a51f68fd0519c0bdfc19a4baa.jpg
# Center: None, Max: None, Min: 29.6, Time: None
# Processing image 59/110: IR_30998_jpg.rf.1efd3818fdc10ec19f8e62746ddfaa64.jpg
# File: IR_30998_jpg.rf.1efd3818fdc10ec19f8e62746ddfaa64.jpg
# Center: None, Max: None, Min: 31.5, Time: None
# Processing image 60/110: IR_31006_jpg.rf.bfc07be235afa6268b7e2a531f08abc9.jpg
# File: IR_31006_jpg.rf.bfc07be235afa6268b7e2a531f08abc9.jpg
# Center: None, Max: None, Min: 31.4, Time: None
# Processing image 61/110: IR_31010_jpg.rf.d1e8ca2adf0420feb2070c44637b1b06.jpg
# File: IR_31010_jpg.rf.d1e8ca2adf0420feb2070c44637b1b06.jpg
# Center: None, Max: None, Min: 26.0, Time: None
# Processing image 62/110: IR_31012_jpg.rf.a662a2c406ccbd77c4a465603a15189e.jpg
# File: IR_31012_jpg.rf.a662a2c406ccbd77c4a465603a15189e.jpg
# Center: None, Max: None, Min: 30.3, Time: None
# Processing image 63/110: IR_31014_jpg.rf.93fae628f15a9883b61809a0654c997b.jpg
# File: IR_31014_jpg.rf.93fae628f15a9883b61809a0654c997b.jpg
# Center: None, Max: 53.5, Min: 30.0, Time: None
# Processing image 64/110: IR_31066_jpg.rf.4be665467d839897ea1f3cd86ea7d4b4.jpg
# File: IR_31066_jpg.rf.4be665467d839897ea1f3cd86ea7d4b4.jpg
# Center: None, Max: None, Min: 26.9, Time: None
# Processing image 65/110: IR_31076_jpg.rf.6183afa29feaa1886602b457600667c4.jpg
# File: IR_31076_jpg.rf.6183afa29feaa1886602b457600667c4.jpg
# Center: None, Max: 40.9, Min: 28.1, Time: None
# Processing image 66/110: IR_31088_jpg.rf.3aef472ccfcb01484a19736e7d6997c8.jpg
# File: IR_31088_jpg.rf.3aef472ccfcb01484a19736e7d6997c8.jpg
# Center: None, Max: None, Min: 30.1, Time: None
# Processing image 67/110: IR_31092_jpg.rf.307270f32bb1497674f06481f0b19de0.jpg
# File: IR_31092_jpg.rf.307270f32bb1497674f06481f0b19de0.jpg
# Center: None, Max: None, Min: 28.6, Time: None
# Processing image 68/110: IR_31096_jpg.rf.b281ad9fad05f73064cada3a3b919d84.jpg
# File: IR_31096_jpg.rf.b281ad9fad05f73064cada3a3b919d84.jpg
# Center: None, Max: None, Min: 28.6, Time: None
# Processing image 69/110: IR_31104_jpg.rf.c66a8ac305dff11a1958915370f0464f.jpg
# File: IR_31104_jpg.rf.c66a8ac305dff11a1958915370f0464f.jpg
# Center: None, Max: None, Min: None, Time: None
# Processing image 70/110: IR_31110_jpg.rf.4b8f31e5809e9d1139207cd08dd1db22.jpg
# File: IR_31110_jpg.rf.4b8f31e5809e9d1139207cd08dd1db22.jpg
# Center: None, Max: None, Min: 30.9, Time: None
# Processing image 71/110: IR_31116_jpg.rf.a8d90646cc5ced1450b1c21b1025fe9e.jpg
# File: IR_31116_jpg.rf.a8d90646cc5ced1450b1c21b1025fe9e.jpg
# Center: None, Max: None, Min: 28.7, Time: None
# Processing image 72/110: IR_31120_jpg.rf.841cbba03db39660b65d9e2d1694dfa9.jpg
# File: IR_31120_jpg.rf.841cbba03db39660b65d9e2d1694dfa9.jpg
# Center: None, Max: None, Min: 30.8, Time: None
# Processing image 73/110: SLOGF20241107101957_jpeg.rf.48e98d5c30cf0cd67b60c9d644bd4cb6.jpg
# File: SLOGF20241107101957_jpeg.rf.48e98d5c30cf0cd67b60c9d644bd4cb6.jpg
# Center: None, Max: None, Min: None, Time: 2024/11/07 10:19
# Processing image 74/110: SLOGF20241107104230_jpeg.rf.24d3f664f4c8c50301d6e3ba8ddae52a.jpg
# File: SLOGF20241107104230_jpeg.rf.24d3f664f4c8c50301d6e3ba8ddae52a.jpg
# Center: 31.8, Max: 34.2, Min: None, Time: 2024/11/07 10:42AM
# Processing image 75/110: SLOGF20241107113131_jpeg.rf.53e18eeb9242a0ce95359a17c8ef8f08.jpg
# File: SLOGF20241107113131_jpeg.rf.53e18eeb9242a0ce95359a17c8ef8f08.jpg
# Center: 29.3, Max: 31.6, Min: 0.93, Time: None
# Processing image 76/110: SLOGF20241107114517_jpeg.rf.ebf2570a2f34ad55a81804848721d339.jpg
# File: SLOGF20241107114517_jpeg.rf.ebf2570a2f34ad55a81804848721d339.jpg
# Center: None, Max: None, Min: 30.3, Time: 2024/11/07 11:45
# Processing image 77/110: SLOGF20241107121125_jpeg.rf.8463e996fe761cfb350265850723f2e1.jpg
# File: SLOGF20241107121125_jpeg.rf.8463e996fe761cfb350265850723f2e1.jpg
# Center: None, Max: None, Min: None, Time: 2024/11/07 12:14
# Processing image 78/110: SLOGF20241107121220_jpeg.rf.ce034adca2d8ac6e9423f8812afd3787.jpg
# File: SLOGF20241107121220_jpeg.rf.ce034adca2d8ac6e9423f8812afd3787.jpg
# Center: None, Max: None, Min: None, Time: 2024/11/07 12:12
# Processing image 79/110: SLOGF20241107121617_jpeg.rf.cffd4b229260017ce0dd161a3d3bade5.jpg
# File: SLOGF20241107121617_jpeg.rf.cffd4b229260017ce0dd161a3d3bade5.jpg
# Center: None, Max: None, Min: None, Time: 2024/11/07 12:16
# Processing image 80/110: SLOGF20241107121652_jpeg.rf.677d874c9c58e508b5b02452a9dbf71f.jpg
# File: SLOGF20241107121652_jpeg.rf.677d874c9c58e508b5b02452a9dbf71f.jpg
# Center: None, Max: None, Min: 29.0, Time: 2024/11/07 12:16
# Processing image 81/110: SLOGF20241107122908_jpeg.rf.f72fa2ffd1572f342fa78eb5a20c31ff.jpg
# File: SLOGF20241107122908_jpeg.rf.f72fa2ffd1572f342fa78eb5a20c31ff.jpg
# Center: 33.3, Max: 51.7, Min: 0.93, Time: 2024/11/07 12:29PM
# Processing image 82/110: SLOGF20241107125316_jpeg.rf.7a59025648f23102fff147cda59a8e8a.jpg
# File: SLOGF20241107125316_jpeg.rf.7a59025648f23102fff147cda59a8e8a.jpg
# Center: None, Max: None, Min: 22.8, Time: 2024/11/07 12:53
# Processing image 83/110: SLOGF20241107141050_jpeg.rf.6149c6d013fa29bab827c2d482eca4c4.jpg
# File: SLOGF20241107141050_jpeg.rf.6149c6d013fa29bab827c2d482eca4c4.jpg
# Center: 31.5, Max: 56.0, Min: None, Time: 2024/11/07 02:10PM
# Processing image 84/110: SLOGF20241107150556_jpeg.rf.9cd5aac69169d200377eac5133e67dd4.jpg
# File: SLOGF20241107150556_jpeg.rf.9cd5aac69169d200377eac5133e67dd4.jpg
# Center: 33.69, Max: 37.5, Min: 20.93, Time: None
# Processing image 85/110: SLOGF20241107150612_jpeg.rf.ba0fa097b20ee6d363a9e501c4aaf7dc.jpg
# File: SLOGF20241107150612_jpeg.rf.ba0fa097b20ee6d363a9e501c4aaf7dc.jpg
# Center: 33.9, Max: 37.8, Min: None, Time: None
# Processing image 86/110: SLOGF20241107150703_jpeg.rf.b374941ee1424ccee6598e468c01f0f8.jpg
# File: SLOGF20241107150703_jpeg.rf.b374941ee1424ccee6598e468c01f0f8.jpg
# Center: None, Max: 40.3, Min: 0.93, Time: 2024/11/07 03:07PM
# Processing image 87/110: SLOGF20241122112728_jpeg.rf.35df3238a80d41106d800cb296e4d2da.jpg
# File: SLOGF20241122112728_jpeg.rf.35df3238a80d41106d800cb296e4d2da.jpg
# Center: 29.2, Max: 37.1, Min: None, Time: 2024/11/22 11:27AM
# Processing image 88/110: SLOGF20241122144706_jpeg.rf.20601e08b21a599f189a3c978561544d.jpg
# File: SLOGF20241122144706_jpeg.rf.20601e08b21a599f189a3c978561544d.jpg
# Center: 31.7, Max: 38.2, Min: None, Time: 2024/11/22 02:47PM
# Processing image 89/110: SLOGF20241122145037_jpeg.rf.28c10b3c716038e8cb68384c51bc7b39.jpg
# File: SLOGF20241122145037_jpeg.rf.28c10b3c716038e8cb68384c51bc7b39.jpg
# Center: 67.9, Max: 72.3, Min: 60.93, Time: 2024/11/22 02:50PM
# Processing image 90/110: SLOGF20241126103757_jpeg.rf.a090e88718110cba00a101381d433a7a.jpg
# File: SLOGF20241126103757_jpeg.rf.a090e88718110cba00a101381d433a7a.jpg
# Center: None, Max: None, Min: None, Time: 2024/11/26 10:37
# Processing image 91/110: SLOGF20241126110949_jpeg.rf.8aae3cc2333d3d7e10adf3899ee8bd12.jpg
# File: SLOGF20241126110949_jpeg.rf.8aae3cc2333d3d7e10adf3899ee8bd12.jpg
# Center: 35.5, Max: 60.2, Min: 60.93, Time: 2024/11/26 11:09AM
# Processing image 92/110: SLOGF20241126112337_jpeg.rf.8ba15e5edbe4c1913bbb2e54fb79aead.jpg
# File: SLOGF20241126112337_jpeg.rf.8ba15e5edbe4c1913bbb2e54fb79aead.jpg
# Center: 31.5, Max: 58.7, Min: 0.93, Time: 2024/11/26 11:23AM
# Processing image 93/110: SLOGF20241126112957_jpeg.rf.1973fa901a8732046cff164407df46e4.jpg
# File: SLOGF20241126112957_jpeg.rf.1973fa901a8732046cff164407df46e4.jpg
# Center: 30.9, Max: 42.4, Min: 0.93, Time: 2024/11/26 11:29AM
# Processing image 94/110: SLOGF20241126114126_jpeg.rf.ada48a22bbb923fec6a91ab804a89aad.jpg
# File: SLOGF20241126114126_jpeg.rf.ada48a22bbb923fec6a91ab804a89aad.jpg
# Center: 29.6, Max: 44.8, Min: 80.93, Time: 2024/11/26 11:41AM
# Processing image 95/110: SLOGF20241126114208_jpeg.rf.2a1ad3c096f4c1ecf97fc9d3a6332580.jpg
# File: SLOGF20241126114208_jpeg.rf.2a1ad3c096f4c1ecf97fc9d3a6332580.jpg
# Center: 32.6, Max: 41.4, Min: 0.93, Time: 2024/11/26 11:42AM
# Processing image 96/110: SLOGF20241126120326_jpeg.rf.81ba3bfa67e9cee2b2ed2207981ac650.jpg
# File: SLOGF20241126120326_jpeg.rf.81ba3bfa67e9cee2b2ed2207981ac650.jpg
# Center: 36.3, Max: 57.7, Min: None, Time: 2024/11/26 12:03PM
# Processing image 97/110: SLOGF20241126121117_jpeg.rf.e2583ff59f9907d3bc412d4e20a255c5.jpg
# File: SLOGF20241126121117_jpeg.rf.e2583ff59f9907d3bc412d4e20a255c5.jpg
# Center: 27.7, Max: 47.4, Min: 0.93, Time: 2024/11/26 12:11PM
# Processing image 98/110: SLOGF20241126121530_jpeg.rf.3300de36bc174240cd45a5dfb13c38b4.jpg
# File: SLOGF20241126121530_jpeg.rf.3300de36bc174240cd45a5dfb13c38b4.jpg
# Center: 28.6, Max: 37.0, Min: 0.93, Time: 2024/11/26 12:15PM
# Processing image 99/110: SLOGF20241126121919_jpeg.rf.2e992b03fc3f5dff7ea0ae6c845c1a30.jpg
# File: SLOGF20241126121919_jpeg.rf.2e992b03fc3f5dff7ea0ae6c845c1a30.jpg
# Center: None, Max: None, Min: 0.93, Time: 2024/11/26 12:19PM
# Processing image 100/110: SLOGF20241126121940_jpeg.rf.6f6d80eec627d9e85657e238c4b01570.jpg
# File: SLOGF20241126121940_jpeg.rf.6f6d80eec627d9e85657e238c4b01570.jpg
# Center: 54.4, Max: None, Min: 0.93, Time: 2024/11/26 12:19PM
# Processing image 101/110: SLOGF20241126123802_jpeg.rf.015a242fcc3db634152b0faa3909d32f.jpg
# File: SLOGF20241126123802_jpeg.rf.015a242fcc3db634152b0faa3909d32f.jpg
# Center: 30.8, Max: 50.5, Min: 0.93, Time: 2024/11/26 12:38PM
# Processing image 102/110: SLOGF20241126144524_jpeg.rf.c6f6dd245af7db9742e1edea998c9d6b.jpg
# File: SLOGF20241126144524_jpeg.rf.c6f6dd245af7db9742e1edea998c9d6b.jpg
# Center: 28.2, Max: 33.5, Min: None, Time: 2024/11/26 02:45PM
# Processing image 103/110: SLOGF20241126151231_jpeg.rf.25a2493fde0f35a812f01637d28215c8.jpg
# File: SLOGF20241126151231_jpeg.rf.25a2493fde0f35a812f01637d28215c8.jpg
# Center: 25.7, Max: 30.7, Min: None, Time: 2024/11/26 03:12PM
# Processing image 104/110: SLOGF20241126151820_jpeg.rf.dd47ef7b9b99626a9ccfa42e290396ef.jpg
# File: SLOGF20241126151820_jpeg.rf.dd47ef7b9b99626a9ccfa42e290396ef.jpg
# Center: 26.1, Max: 28.6, Min: 0.93, Time: 2024/11/26 03:18PM
# Processing image 105/110: SLOGF20241127094222_jpeg.rf.d6958bd98bd009d6d1dd224b9d0ef7b6.jpg
# File: SLOGF20241127094222_jpeg.rf.d6958bd98bd009d6d1dd224b9d0ef7b6.jpg
# Center: 38.1, Max: 57.5, Min: None, Time: None
# Processing image 106/110: SLOGF20241127113817_jpeg.rf.4de35aa78d5db442fb302dbe7d605158.jpg
# File: SLOGF20241127113817_jpeg.rf.4de35aa78d5db442fb302dbe7d605158.jpg
# Center: 46.2, Max: 49.4, Min: 0.93, Time: 2024/11/27 11:38AM
# Processing image 107/110: SLOGF20241127115609_jpeg.rf.7f8471a7c70399e73ea44c45a27094dd.jpg
# File: SLOGF20241127115609_jpeg.rf.7f8471a7c70399e73ea44c45a27094dd.jpg
# Center: 37.2, Max: 51.5, Min: 510.93, Time: 2024/11/27 11:56AM
# Processing image 108/110: SLOGF20241127133151_jpeg.rf.e0f6a520553d5cca8717c5a75624c5ce.jpg
# File: SLOGF20241127133151_jpeg.rf.e0f6a520553d5cca8717c5a75624c5ce.jpg
# Center: 28.8, Max: 36.2, Min: 0.93, Time: 2024/11/27 01:31PM
# Processing image 109/110: SLOGF20241127134556_jpeg.rf.3e5a01432dbb76e591fe2842b7ad8b53.jpg
# File: SLOGF20241127134556_jpeg.rf.3e5a01432dbb76e591fe2842b7ad8b53.jpg
# Center: 46.0, Max: 55.6, Min: None, Time: 2024/11/27 01:45PM
# Processing image 110/110: SLOGF20241127150109_jpeg.rf.ad06a64904bbb0f2e33eb80599482b59.jpg
# File: SLOGF20241127150109_jpeg.rf.ad06a64904bbb0f2e33eb80599482b59.jpg
# Center: None, Max: None, Min: 10.93, Time: 2024/11/27 03:01PM
# Data extracted and saved to C:\Users\Anuska Palit\OneDrive\Desktop\project\Computer Vision\data3.csv

# %%
import pandas as pd

files = ["data1.csv", "data2.csv", "data3.csv"]
df_list = [pd.read_csv(file) for file in files]

merged_df = pd.concat(df_list, ignore_index=True)

# Fill NaN values with the mean of each column
merged_df.fillna(merged_df.mean(numeric_only=True), inplace=True)

merged_df.to_csv("data.csv", index=False)

# %%
import flask
from flask import request, jsonify
import joblib
import tensorflow as tf

app = flask.Flask(__name__)
model = tf.keras.models.load_model("autoencoder_model.h5")
scaler = joblib.load("scaler.pkl")

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()
    input_data = np.array([data["center_temp"], data["max_temp"], data["min_temp"], data["temp_range"]]).reshape(1, -1)
    input_data = scaler.transform(input_data)
    input_data = np.expand_dims(input_data, axis=2)

    # Predict reconstruction error
    reconstructed = model.predict(input_data)
    reconstruction_loss = np.mean(np.abs(input_data - reconstructed))

    # Compare with threshold
    anomaly = int(reconstruction_loss > threshold)

    return jsonify({"anomaly_detected": anomaly, "reconstruction_loss": float(reconstruction_loss)})

if __name__ == "__main__":
    app.run(port=5000)
